# %% [markdown]
# <a href="https://colab.research.google.com/github/stefgina/tiny-encoders-decoders/blob/main/transformer-huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentencepiece
import sentencepiece
from transformers import MarianMTModel, MarianTokenizer
import torch

# Ensure you have an active internet connection for this step
# Load the pre-trained model and tokenizer
model_name = 'Helsinki-NLP/opus-mt-en-el'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Translation function
def translate(text, model, tokenizer):
    # Tokenize the input text and convert to tensor
    inputs = tokenizer(text, return_tensors="pt", padding=True)

    # Generate translation using model
    translated = model.generate(**inputs)

    # Decode the translated text
    translated_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    return translated_text

# Example usage
english_text = "Hello, how are you?"
greek_translation = translate(english_text, model, tokenizer)
print(greek_translation)
# Out:
# ...
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/787k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# ['Γεια σου, πώς είσαι;']
